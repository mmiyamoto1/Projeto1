# %% [markdown]
# <a href="https://colab.research.google.com/github/mmiyamoto1/diamond_price/blob/marcelo/diamond_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # README
#
# How to determine the price of a diamond:
#
#
# *   Carat weight of the diamond
# *  Cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# *  color diamond colour, from J (worst) to D (best)
# *  clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# *  x length in mm
# *  y width in mm
# *  z depth in m
# *  depth: The height of a diamond
# *  table: The width of the diamond’s table expressed as a percentage of its average diameter

# %%
#libraries import

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt, pylab as pylab
from sklearn import *

# %%
data_rick_diamonds = pd.read_csv('https://raw.githubusercontent.com/mmiyamoto1/diamond_price/main/rick_diamonds.csv')
data_rick_diamonds
# Out:
#       carat        cut color clarity  depth  table     x     y     z
# 0      0.91  Very Good     H     SI2   63.4   57.0  6.10  6.18  3.89
# 1      0.38       Good     F     VS2   60.3   61.0  4.68  4.71  2.83
# 2      0.52      Ideal     H     VS2   61.8   56.0  5.19  5.16  3.20
# 3      1.10      Ideal     G     VS1   61.3   56.0  6.65  6.69  4.09
# 4      2.28      Ideal     G     SI2   61.6   57.0  8.44  8.37  5.18
# ...     ...        ...   ...     ...    ...    ...   ...   ...   ...
# 4995   0.30  Very Good     D     SI2   62.2   59.0  4.25  4.30  2.66
# 4996   0.51      Ideal     F    VVS2   61.9   56.0  5.09  5.14  3.16
# 4997   1.01  Very Good     F     SI1   60.6   60.0  6.37  6.43  3.88
# 4998   0.31      Ideal     F    VVS1   62.1   56.0  4.35  4.38  2.71
# 4999   0.33      Ideal     E     VS2   61.8   55.0  4.45  4.48  2.76
#
# [5000 rows x 9 columns]

# %%
          data_diamonds = pd.read_csv('https://raw.githubusercontent.com/mmiyamoto1/diamond_price/main/diamonds.csv')
data_diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 1       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 2       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 3       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 4       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 48935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 48936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 48937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 48938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 48939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [48940 rows x 10 columns]

# %%
'''
df['coluna'].max() ou > quantidade
df['coluna'].plot()
sns.pairplot(df[df['coluna']<10000])
sns.displot(df['coluna'], kind='hist/kde')
sns.catplot(df_clean['coluna'], kind='hist') compara uma categorica com uma categorica ou numerica
sns.relplot = faz o resumo de graficos
df.corr()



Importações

Limpeza

Graficos

Treinamento  modelo

Deploy
'''
# Out:
# "\ndf['coluna'].max() ou > quantidade\ndf['coluna'].plot()\nsns.pairplot(df[df['coluna']<10000])\nsns.displot(df['coluna'], kind='hist/kde')\nsns.catplot(df_clean['coluna'], kind='hist') compara uma categorica com uma categorica ou numerica\nsns.relplot = faz o resumo de graficos\ndf.corr()\n\n\n\nImportações\n\nLimpeza\n\nGraficos\n\nTreinamento  modelo\n\nDeploy\n"

# %% [markdown]
# Data Visualization

# %%
sns.pairplot(data_diamonds)

# %%
data_diamonds['x'].apply(lambda x : x if x [data_diamonds['x'] != 0 else = np.nan])
# Out:
#   File "<ipython-input-15-13fdd98956a1>", line 1
#     data_diamonds['x'].apply(lambda x : x if x data_diamonds[data_diamonds['x'] != 0] else = np.nan])
#                                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Data Preprocessing
#
#
#
# *   Dataset Overview (info, shape, head, describe)
# *   Data Cleaning (dealing with null values, drop, etc)
# *   Enconding categorial x numerical variables

# %% [markdown]
# Cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color diamond colour, from J (worst) to D (best)
#
# clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))

# %%
from sklearn.linear_model import LinearRegression

X=data_diamonds[['carat']]
y=data_diamonds['price']

model = LinearRegression()
model.fit(X,y)

data_rick_diamonds['price_predicted'] = model.predict(data_rick_diamonds[['carat']])

# %%
data_rick_diamonds
# Out:
#       carat        cut color clarity  depth  table     x     y     z  \
# 0      0.91  Very Good     H     SI2   63.4   57.0  6.10  6.18  3.89
# 1      0.38       Good     F     VS2   60.3   61.0  4.68  4.71  2.83
# 2      0.52      Ideal     H     VS2   61.8   56.0  5.19  5.16  3.20
# 3      1.10      Ideal     G     VS1   61.3   56.0  6.65  6.69  4.09
# 4      2.28      Ideal     G     SI2   61.6   57.0  8.44  8.37  5.18
# ...     ...        ...   ...     ...    ...    ...   ...   ...   ...
# 4995   0.30  Very Good     D     SI2   62.2   59.0  4.25  4.30  2.66
# 4996   0.51      Ideal     F    VVS2   61.9   56.0  5.09  5.14  3.16
# 4997   1.01  Very Good     F     SI1   60.6   60.0  6.37  6.43  3.88
# 4998   0.31      Ideal     F    VVS1   62.1   56.0  4.35  4.38  2.71
# 4999   0.33      Ideal     E     VS2   61.8   55.0  4.45  4.48  2.76
#
#       price_predicted
# 0         4804.879333
# 1          692.422362
# 2         1778.731751
# 3         6279.156361
# ...

# %%
data_rick_diamonds.to_csv('diamond_model1.csv',index=False)

# %%
from google.colab import files
files.download("diamond_model1.csv")
